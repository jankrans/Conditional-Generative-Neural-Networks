# %%
import os
import numpy as np
import pandas as pd
from wwo_hist import retrieve_hist_data

consumption_dir = r'C:\Thesis\data\data_full\per_day\data_Consumption_per_day.pkl'
injection_dir = r'C:\Thesis\data\data_full\per_day\data_Injection_per_day.pkl'
offtake_dir = r'C:\Thesis\data\data_full\per_day\data_Offtake_per_day.pkl'

consumption = pd.read_pickle(consumption_dir)
injection = pd.read_pickle(injection_dir)
offtake = pd.read_pickle(offtake_dir)
location_list = ['brussels']
API_KEY = 'c3ecb790d31840f5a79171238231602'

# %%
dates = consumption.index.levels[1]
str(max(dates))
# Out:
# '2021-12-31'

# %%
start_date = str(min(dates))
end_date = str(max(dates))
location_list = ['brussels']
API_KEY = 'c3ecb790d31840f5a79171238231602'
hist_weather_data = retrieve_hist_data(
    api_key = API_KEY, 
    location_list = location_list, 
    start_date = start_date, 
    end_date = end_date,
    frequency = 24,
    export_csv=False,
    store_df = True)
# Out:
# Retrieving weather data for brussels
#
#
# Currently retrieving data for brussels: from 2016-01-01 to 2016-01-31
# c:\Users\jankr\miniconda3\lib\site-packages\wwo_hist\__init__.py:69: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   list_mon_begin = pd.date_range(start_date, end_date, freq='MS', closed='right')
# c:\Users\jankr\miniconda3\lib\site-packages\wwo_hist\__init__.py:74: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   list_mon_end = pd.date_range(start_date, end_date, freq='M', closed='left')
# Time elapsed (hh:mm:ss.ms) 0:00:00.246281
# Currently retrieving data for brussels: from 2016-02-01 to 2016-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:00.453770
# Currently retrieving data for brussels: from 2016-03-01 to 2016-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.676204
# Currently retrieving data for brussels: from 2016-04-01 to 2016-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:00.884870
# ...

# %%
out = os.path.join(r'C:\Thesis\data\data_full','weather_data2016-2021.pkl')
hist_weather_data[0].to_pickle(out)

# %%
hist_weather_data = retrieve_hist_data(
    api_key = API_KEY, 
    location_list = location_list, 
    start_date = '2021-01-01', 
    end_date = '2021-12-31',
    frequency = 24,
    export_csv=False,
    store_df = True)
hist_weather_data = hist_weather_data[0].set_index('date_time')
# Out:
# Retrieving weather data for brussels
#
#
# Currently retrieving data for brussels: from 2021-01-01 to 2021-01-31
# c:\Users\jankr\miniconda3\lib\site-packages\wwo_hist\__init__.py:69: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   list_mon_begin = pd.date_range(start_date, end_date, freq='MS', closed='right')
# c:\Users\jankr\miniconda3\lib\site-packages\wwo_hist\__init__.py:74: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   list_mon_end = pd.date_range(start_date, end_date, freq='M', closed='left')
# Time elapsed (hh:mm:ss.ms) 0:00:00.417930
# Currently retrieving data for brussels: from 2021-02-01 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:00.805136
# Currently retrieving data for brussels: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.218807
# Currently retrieving data for brussels: from 2021-04-01 to 2021-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:02.644753
# ...

# %%
hist_weather_data.columns
# Out:
# Index(['maxtempC', 'mintempC', 'totalSnow_cm', 'sunHour', 'uvIndex',
#        'moon_illumination', 'moonrise', 'moonset', 'sunrise', 'sunset',
#        'DewPointC', 'FeelsLikeC', 'HeatIndexC', 'WindChillC', 'WindGustKmph',
#        'cloudcover', 'humidity', 'precipMM', 'pressure', 'tempC', 'visibility',
#        'winddirDegree', 'windspeedKmph', 'location'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
for col in ['maxtempC', 'mintempC', 'totalSnow_cm','sunHour', 'moon_illumination','DewPointC', 'FeelsLikeC', 'HeatIndexC', 'WindChillC', 'WindGustKmph',
       'cloudcover', 'humidity', 'precipMM', 'pressure', 'tempC', 'visibility','windspeedKmph']:
    plt.plot(hist_weather_data[col].values.astype('float'))
    plt.title(col)
    plt.show()
